# %%
import pandas as pd
url = "https://raw.githubusercontent.com/mricardo89/data-mining/main/Unit-II/datasets/titanic.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
'''
Pregunta A: La diferencia matematica entre el tercer cuartil y el valor maxima es de 481.32
lo que nos dice esta diferencia es que habian unos precios exagerados entre el tercer cuartil y el valor maximo.
Por lo que podemos inferir que la mayoria de personas que estaban en el barco tomaron boletos baratos y solo
un pequeño porcentaje pudo pagar un boleto de primera clase
'''
# Out:
# '\nPregunta A: La diferencia matematica entre el tercer cuartil y el valor maxima es de 481.32\nlo que nos dice esta diferencia es que habian unos precios exagerados entre el tercer cuartil y el valor maximo.\nPor lo que podemos inferir que la mayoria de personas que estaban en el barco tomaron boletos baratos y solo\nun pequeño porcentaje pudo pagar un boleto de primera clase\n'

# %%
'''
Pregunta B: Se puede observar que el PassengerID tiene 891 valores y Age solamente tiene 714 valores.
Esa es una anomalía en la base de datos ya que en la tabla age faltaron valores
'''
# Out:
# '\nPregunta B: Se puede observar que el PassengerID tiene 891 valores y Age solamente tiene 714 valores.\nEsa es una anomalía en la base de datos ya que en la tabla age faltaron valores\n'

# %%
'''
Lo que podemos hacer a nivel base de datos para mitigar el problema puede ser rellenar los datos con la mediana
de los valores que tenemos ya que la mitad es 28 y el mean dentro de age es de 29.

'''
